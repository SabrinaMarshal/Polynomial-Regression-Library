# %%
# !pip install PolynomialRegression==0.0.1
# Out:
# ...
#   Created wheel for PolynomialRegression: filename=PolynomialRegression-0.0.1-py3-none-any.whl size=3588 sha256=b49434d667426e217a260933723841932e7384f959f3ee769ebfbfa09bf86d14
#   Stored in directory: c:\users\sabrina\appdata\local\pip\cache\wheels\5f\cb\d6\a17ccfe73421baf0983af8f3edab781cb6f22bd13bf84bb620
# ...
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1309 sha256=a073fde0787a7976e2bd52e2347d13a7a216c8d64d8738baf0fe89dd9b90933a
#   Stored in directory: c:\users\sabrina\appdata\local\pip\cache\wheels\22\0b\40\fd3f795caaa1fb4c6cb738bc1f56100be1e57da95849bfc897
# Successfully built PolynomialRegression sklearn
# ...

# %%
import numpy as np
import pandas as pd
from sklearn import metrics
import PolynomialRegression as pr

# %%
df=pd.read_csv("boston.csv")
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
deg=pr.best_hypothesis(df)
deg
# Out:
# [2, 6, 4, 1, 2.2, 6.5, 20, 0.1, 0.6, 0.1, 0.1, 0.3, 0.1]

# %%
W,gx=pr.normal_eqn(df,deg)
gx
# Out:
# [29.710442536783987,
#  23.755224195250975,
#  32.98714347507105,
#  33.72987971781292,
#  29.853097291715514,
#  27.489254471973368,
#  20.974612951893704,
#  17.40280807546975,
#  12.593313089108818,
#  17.269529626674057,
#  16.836727066224213,
#  19.822237869461887,
#  18.825900312314232,
#  20.186765599078626,
#  18.884751856131743,
#  20.027662433337113,
#  22.204200054076125,
#  15.895775752232467,
#  17.262854243489073,
#  18.33800896364974,
#  13.020151528350937,
#  16.739417130435612,
#  14.515573627266448,
#  13.707916722631296,
#  14.879256182786136,
#  13.710368248186015,
#  15.057367097734769,
#  14.026567342386628,
#  18.129764267730295,
#  19.31016707143192,
#  11.70549061242221,
#  17.672077578299096,
#  9.727119773278645,
#  14.16123442713662,
#  13.489545845294842,
#  23.198890485264826,
#  21.5662425909033,
#  23.08271454626899,
#  22.173159841551225,
#  30.918903713424115,
#  38.22168462743585,
#  29.88276507306503,
#  26.8159676816921,
#  24.96413005792739,
# ...

# %%
print('Mean Squared Error:', metrics.mean_squared_error(df.iloc[:,13],gx))
# Out:
# Mean Squared Error: 14.777593903706233
