# %%
import numpy as np
import pandas as pd

# %%
def normal_eqn(df,deg):
    df2=df.copy()
    for i in range(len(deg)):
        dpow=np.power(df2.iloc[:,i],deg[i])
        df2.iloc[:,i]=dpow
    n=len(df2.columns)-1
    D=df2.iloc[:,0:n].to_numpy()
    D=np.insert(D,0,1,axis=1)
    R=df2.iloc[:,n].to_numpy()
    DT=np.transpose(D)
    DTD=np.matmul(DT,D)
    DTDinv=np.linalg.inv(DTD)
    DTR=np.matmul(DT,R)
    W=np.matmul(DTDinv,DTR)
    gx=W[0]
    for i in range(n):
        gx+=W[i+1]*df2.iloc[:,i]
        i+=1
    gx=gx.tolist()
    return W,gx

# %%
df=pd.read_csv("boston.csv")   #reading the dataset
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %% [markdown]
# Hypothesis: $w_{0}$+$w_{1}$$x_{1}^{1}$+$w_{2}$$x_{2}^{2}$+$w_{3}$$x_{3}^{1/2}$+$w_{4}$$x_{4}^{3}$+$w_{5}$$x_{5}^{1}$+$w_{6}$$x_{6}^{4}$+$w_{7}$$x_{7}^{2.6}$+$w_{8}$$x_{8}^{5}$+$w_{9}$$x_{9}^{4.1}$+$w_{10}$$x_{10}^{3}$+$w_{11}$$x_{11}^{3}$+$w_{12}$$x_{12}^{1}$+$w_{13}$$x_{13}^{2.2}$

# %%
deg=[1,2,0.5,3,1,4,2.6,5,4.1,3,3,1,2.2]   #degree of each term in the hypothesis

# %%
W,gx=normal_eqn(df,deg)   #calling the normal equation function

# %%
W  #weights
# Out:
# array([ 2.17555915e+01, -1.06379525e-01,  2.43066051e-04,  1.13555130e-01,
#         2.91615813e+00, -1.02594130e+01,  5.67252391e-03,  2.10361447e-06,
#        -2.74178328e-05,  8.63563064e-06, -1.01900639e-08, -9.08532179e-04,
#         1.12644083e-02, -3.78103458e-03])

# %%
gx  #target/dependent variable
# Out:
# [27.989600236763458,
#  25.69352642081869,
#  31.445977550291204,
#  28.99740000619211,
#  30.129714437707662,
#  25.021817502182742,
#  24.105901614624898,
#  23.52596013711345,
#  16.702384338879607,
#  22.887119084640545,
#  24.136150290703032,
#  23.931005738487787,
#  22.734754036744903,
#  19.0009354887863,
#  19.432748889389735,
#  18.42380899975918,
#  18.862036085376328,
#  18.195953827227584,
#  15.208206002514205,
#  17.609339253574504,
#  14.646163403268645,
#  18.362517702195245,
#  18.124452544559887,
#  16.254542447345088,
#  17.68585183242694,
#  15.12625832123722,
#  17.276944762526057,
#  16.98853903472689,
#  21.443562321943567,
#  22.589569288686047,
#  14.477828714591302,
#  18.888267765123487,
#  11.965392221281231,
#  15.756837552853607,
#  15.741901141865636,
#  21.31424497087969,
#  20.39402382192177,
#  20.932848959695058,
#  21.242602702268204,
#  28.16688978592041,
#  31.31669387867388,
#  28.07349272448548,
#  24.288728340734497,
#  24.506575869634844,
# ...

# %%
from sklearn import metrics
print('Mean Squared Error:', metrics.mean_squared_error(df.iloc[:,13],gx))
# Out:
# Mean Squared Error: 23.761400515336334

# %%
df=pd.read_csv("CyclePowerPlant.csv")   #Trying with another dataset
df.head()
# Out:
#       AT      V       AP     RH      PE
# 0  14.96  41.76  1024.07  73.17  463.26
# 1  25.18  62.96  1020.04  59.08  444.37
# 2   5.11  39.40  1012.16  92.14  488.56
# 3  20.86  57.32  1010.24  76.64  446.48
# 4  10.82  37.50  1009.23  96.62  473.90

# %% [markdown]
# Hypothesis: $w_{0}$+$w_{1}$$x_{1}^{2.1}$+$w_{2}$$x_{2}^{1.3}$+$w_{3}$$x_{1}^{1}$+$w_{4}$$x_{4}^{1.6}$

# %%
deg=[1,1,1,1]

# %%
W,gx=normal_eqn(df,deg)

# %%
W
# Out:
# array([ 3.17009982e+02, -2.82844906e-02, -9.16739774e-02,  1.74169036e-01,
#        -5.39123040e-03])

# %%
gx
# Out:
# 0       470.162817
# 1       446.227288
# 2       474.057866
# 3       453.000642
# 4       470.300414
#            ...
# 9563    461.181053
# 9564    473.659158
# 9565    427.755827
# 9566    443.518275
# 9567    451.822278
# Name: AT, Length: 9568, dtype: float64

# %%
print('Mean Squared Error:', metrics.mean_squared_error(df.iloc[:,4],gx))
# Out:
# Mean Squared Error: 20.76739753253501
